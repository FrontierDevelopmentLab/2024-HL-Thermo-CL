# %%
import wandb

# %%
wandb.init(project="karman",entity='sceki')
# Out:
# Finishing last run (ID:2bua6nc1) before initializing another...
# ...
#  View run <strong style="color:#cdcd00">proud-puddle-1</strong> at: <a href='https://wandb.ai/trilliumtechnologies/karman/runs/2bua6nc1' target="_blank">https://wandb.ai/trilliumtechnologies/karman/runs/2bua6nc1</a><br/> View project at: <a href='https://wandb.ai/trilliumtechnologies/karman' target="_blank">https://wandb.ai/trilliumtechnologies/karman</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240714_120627-2bua6nc1/logs</code>
# Successfully finished last run (ID:2bua6nc1). Initializing new run:<br/>
# ...
# Problem at: /home/ga00693/mambaforge/envs/karman_hl_2024/lib/python3.12/site-packages/wandb/sdk/wandb_init.py 849 getcaller
# wandb: ERROR Error while calling W&B API: permission denied (<Response [403]>)
# ---------------------------------------------------------------------------
# ...

# %%
wandb.entity
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 wandb.entity
#
# AttributeError: module 'wandb' has no attribute 'entity'
